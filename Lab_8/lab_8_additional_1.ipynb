# %%
import numpy as np
import pandas as pd
from nltk.tokenize import word_tokenize
import nltk
from functools import reduce
import string
from pymorphy2 import MorphAnalyzer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /Users/kyryl/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/kyryl/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
morph_uk = MorphAnalyzer(lang='uk')


def remove_punctuation(text):
    text = text.translate(str.maketrans('', '', string.punctuation + '«»—–-’'))
    return text.replace('\n', ' ').replace(' ', ' ')


def tokenize_text(text):
    words = word_tokenize(text, language='russian')
    return [morph_uk.parse(word)[0].normal_form for word in words]


with open('../data/stopwords_ua.txt') as file:
    ukrainian_stopwords = set(file.read().splitlines())


def remove_stopwords(words):
    return [word for word in words if word not in ukrainian_stopwords]

# %%
def transform_text(text):
    return reduce(lambda text, function: function(text),
                  [remove_punctuation, tokenize_text, remove_stopwords], text)

# %%
ukr_text_df = pd.read_csv('../data/ukr_text.csv')
ukr_text_df.columns = ukr_text_df.columns.str.lower()
ukr_text_df.head()
# Out:
#                                    id  \
# 0  http://k.img.com.ua/rss/ua/4013798
# 1  http://k.img.com.ua/rss/ua/4001679
# 2  http://k.img.com.ua/rss/ua/4001390
# 3  http://k.img.com.ua/rss/ua/4001239
# 4  http://k.img.com.ua/rss/ua/4001227
#
#                                                title  \
# 0      Кличко покликав німецьких інвесторів до Києва
# 1  З'явилося відео, як байкер почав стріляти у во...
# 2        У центрі Києва посеред вулиці помер чоловік
# 3       Нічний ураган перетворив Хрещатик на смітник
# 4      Потоп у Києві: столицю накрив ураган з градом
#
#                                                 body
# 0  Київ - перспективний і відкритий ринок для біз...
# 1     З'явилося відео конфлікту між мотоциклістом...
# 2  У Києві на Бессарабській площі вранці в четвер...
# 3  Київ вночі 16 серпня пережив найсильнішу грозу...
# 4  Уночі Київ вкотре накрила негода. Найсильніший...

# %%
ukr_text_df['words'] = ukr_text_df['body'].apply(transform_text)
ukr_text_df.head()
# Out:
#                                    id  \
# 0  http://k.img.com.ua/rss/ua/4013798
# 1  http://k.img.com.ua/rss/ua/4001679
# 2  http://k.img.com.ua/rss/ua/4001390
# 3  http://k.img.com.ua/rss/ua/4001239
# 4  http://k.img.com.ua/rss/ua/4001227
#
#                                                title  \
# 0      Кличко покликав німецьких інвесторів до Києва
# 1  З'явилося відео, як байкер почав стріляти у во...
# 2        У центрі Києва посеред вулиці помер чоловік
# 3       Нічний ураган перетворив Хрещатик на смітник
# 4      Потоп у Києві: столицю накрив ураган з градом
#
#                                                 body  \
# 0  Київ - перспективний і відкритий ринок для біз...
# 1     З'явилося відео конфлікту між мотоциклістом...
# 2  У Києві на Бессарабській площі вранці в четвер...
# 3  Київ вночі 16 серпня пережив найсильнішу грозу...
# 4  Уночі Київ вкотре накрила негода. Найсильніший...
#
#                                                words
# 0  [перспективний, відкритий, ринок, бізнес, інве...
# 1  [зявитися, відео, конфлікт, мотоцикліст, водій...
# 2  [бессарабський, площа, вранці, четвер, 16, сер...
# 3  [вночі, 16, серпень, пережити, найсильніший, г...
# 4  [уночі, вкотре, накрити, негода, найсильніший,...

# %%
tone_df = pd.read_csv('https://raw.githubusercontent.com/lang-uk/tone-dict-uk/master/tone-dict-uk.tsv', delimiter='\t', names=['word', 'tone'], index_col=0)
tone_df.head()
# Out:
#            tone
# word
# Всевишній     1
# Господь       1
# Христовий     1
# аборт        -1
# абсурд       -1

# %%
def calculate_tone(words):
    tone_words = [word for word in words if word in tone_df.index]
    if len(set(tone_words)) < 5:
        return 0
    return sum([tone_df.loc[word].tone if word in tone_df.index else 0 for word in words]) / len(words)

ukr_text_df['tone'] = ukr_text_df['words'].apply(calculate_tone)
ukr_text_df.head()
# Out:
#                                    id  \
# 0  http://k.img.com.ua/rss/ua/4013798
# 1  http://k.img.com.ua/rss/ua/4001679
# 2  http://k.img.com.ua/rss/ua/4001390
# 3  http://k.img.com.ua/rss/ua/4001239
# 4  http://k.img.com.ua/rss/ua/4001227
#
#                                                title  \
# 0      Кличко покликав німецьких інвесторів до Києва
# 1  З'явилося відео, як байкер почав стріляти у во...
# 2        У центрі Києва посеред вулиці помер чоловік
# 3       Нічний ураган перетворив Хрещатик на смітник
# 4      Потоп у Києві: столицю накрив ураган з градом
#
#                                                 body  \
# 0  Київ - перспективний і відкритий ринок для біз...
# 1     З'явилося відео конфлікту між мотоциклістом...
# 2  У Києві на Бессарабській площі вранці в четвер...
# 3  Київ вночі 16 серпня пережив найсильнішу грозу...
# 4  Уночі Київ вкотре накрила негода. Найсильніший...
#
#                                                words      tone
# 0  [перспективний, відкритий, ринок, бізнес, інве...  0.026163
# 1  [зявитися, відео, конфлікт, мотоцикліст, водій... -0.090909
# 2  [бессарабський, площа, вранці, четвер, 16, сер... -0.137255
# 3  [вночі, 16, серпень, пережити, найсильніший, г...  0.000000
# 4  [уночі, вкотре, накрити, негода, найсильніший,...  0.000000

# %%
print(ukr_text_df.sort_values(by='tone').iloc[0]['body'])
# Out:
# У Державному департаменті США заявили, що США разом з усім світом згадують жертв Голодомору і вкотре підтвердили прихильність демократії, процвітанню і суверенітету України. Про це йдеться в заяві Держдепу, передає Голос Америки. Прес-секретар Державного департаменту США Морган Ортагюс заявила: "Ми об'єднуємося з усім світом, щоб згадати невинних жертв Голодомору і підтвердити нашу прихильність демократії, процвітанню і суверенітету України". У Держдепі заявили, що Голодомор - одна з найжорстокіших трагедій 20 століття. "Шляхом навмисного захоплення української землі, врожаю і примусової колективізації, Радянський Союз призвів до масштабного голоду, смертей і приніс надзвичайні людські страждання ... Хоча ця жахлива трагедія була однією з найжорстокіших в 20 столітті, Радянському Союзу не вдалося зломити дух українського народу". Раніше повідомлялося, що в Україні відзначають День пам'яті жертв Голодоморів. По всій території України приспущено державні прапори й обмежено проведення заходів розважального характеру.

# %%
print(ukr_text_df.sort_values(by='tone', ascending=False).iloc[0]['body'])
# Out:
# Тільки на мовних курсах у Великій Британії учень з головою може зануритися в природне мовне середовище і отримати безцінний багаж знань. Однак, чим англійська освіта на мовних курсах відрізняється від навчання в інших країнах? Що робить вивчення англійської в Великобританії настільки особливим, що кожен іноземний студент, мріє відправитися на вивчення англійської саме в цю країну? У цій статті, підготувати яку нам допомогло освітнє агентство PFI, ми пропонуємо Вам 5 цікавих фактів про мовні курси в Англії.   Концентрація на розмовних навичках Головною відмінністю мовних курсів в Англії є фокус на розвитку розмовних і комунікативних навичок абітурієнта. Кваліфіковані куратори груп планують навчальний процес таким чином, щоб теоретична частина займала 20%, а практика - 80%. Подібний підхід до навчання вперше застосували навчальні заклади Великобританії, рані
# 1        З'явилося відео конфлікту між мотоциклістом...
# 2     У Києві на Бессарабській площі вранці в четвер...
# 3     Київ вночі 16 серпня пережив найсильнішу грозу...
# 4     Уночі Київ вкотре накрила негода. Найсильніший...
# ...                                                 ...
# 1117  Київський офіс Класичного ювелірного дому Лобо...
# 1118  20 років тому орден За заслуги – тоді він нази...
# 1119  10 жовтня політичні важковаговики з табору опо...
# 1120  Добре там, де нас немає. В Ізраїлі ми є, але т...
# 1121  Початок розмови Корреспондента зі знаменитим у...
#
#                                                   words      tone  \
# 0     [перспективний, відкритий, ринок, бізнес, інве...  0.026163
# 1     [зявитися, відео, конфлікт, мотоцикліст, водій... -0.090909
# 2     [бессарабський, площа, вранці, четвер, 16, сер... -0.137255
# 3     [вночі, 16, серпень, пережити, найсильніший, г...  0.000000
# 4     [уночі, вкотре, накрити, негода, найсильніший,...  0.000000
# ...                                                 ...       ...
# 1117  [київський, офіс, класичний, ювелірний, дома, ...  0.042616
# 1118  [20, том, орден, заслуга, називатися, почесний...  0.124682
# 1119  [10, жовтень, політичний, важковаговик, табір,...  0.022042
# 1120  [ізраїль, країна, займати, місце, світ, надій,...  0.018657
# 1121  [початок, розмова, корреспондент, знаменитий, ...  0.020802
#
#                                         normalized_text
# 0     перспективний відкритий ринок бізнес інвестиці...
# 1     зявитися відео конфлікт мотоцикліст водій авто...
# 2     бессарабський площа вранці четвер 16 серпень в...
# 3     вночі 16 серпень пережити найсильніший гроза з...
# 4     уночі вкотре накрити негода найсильніший дощ п...
# ...                                                 ...
# 1117  київський офіс класичний ювелірний дома лоборт...
# 1118  20 том орден заслуга називатися почесний знак ...
# 1119  10 жовтень політичний важковаговик табір опози...
# 1120  ізраїль країна займати місце світ надій молоко...
# 1121  початок розмова корреспондент знаменитий украї...
#
# [1122 rows x 6 columns]

# %%
tfidf_vectorizer = TfidfVectorizer()
X = tfidf_vectorizer.fit_transform(ukr_text_df['normalized_text'])

# %%
svd_vectorizer = TruncatedSVD(n_components=100, random_state=42)
X_lsa = svd_vectorizer.fit_transform(X)

# %%
X_lsa
# Out:
# array([[ 0.22554268, -0.01841248,  0.07070091, ..., -0.02838924,
#          0.01491171,  0.00846253],
#        [ 0.09406398, -0.02790445, -0.0320689 , ...,  0.07981946,
#          0.01932493, -0.04900203],
#        [ 0.09417164, -0.02188734, -0.03898791, ...,  0.04596805,
#          0.07591701, -0.02015498],
#        ...,
#        [ 0.20440434, -0.0483453 , -0.00387152, ..., -0.02651493,
#         -0.01794904, -0.06926745],
#        [ 0.21970905, -0.02814167,  0.03929289, ..., -0.01025367,
#         -0.03825015, -0.04493127],
#        [ 0.24004565, -0.07530466, -0.05597721, ..., -0.04029973,
#          0.03659069, -0.1107553 ]])

# %%
def get_category_words(vectorizer, svd, n_top_words):
    words = vectorizer.get_feature_names_out()
    topics = []
    for component in svd.components_:
        top_words_idx = np.argsort(component)[::-1][:n_top_words]
        top_words = [words[i] for i in top_words_idx]
        topics.append(top_words)
    return topics

# %%
categories = get_category_words(tfidf_vectorizer, svd_vectorizer, 10)
for i, category in enumerate(categories):
    print(f'Words in category {i}: {", ".join(category)}')
# Out:
# Words in category 67: роналд, alibaba, магазин, олександрія, whatsapp, uber, кріштіану, млн, травень, виявити
# Words in category 68: мільйон, поїзд, бренд, коньяк, назва, пасажир, кубометр, китай, rollsroyce, мен
# Words in category 69: азс, бал, зірка, грн, пісня, пожежа, листопад, галактика, вчений, збірний
# Words in category 70: google, автомобіль, тонна, вчений, динамо, невагомість, галактика, угода, мандарин, гаєк
# Words in category 71: 18pt, fontsize, uber, актор, фсб, вчений, співробітник, стрілянина, долар, google
# Words in category 72: електромобіль, місце, олімпійський, китай, команда, млн, google, супутник, сезон, дтп
# Words in category 73: грм, білка, млн, тариф, фсб, маркл, підвищити, стрілянина, динамо, екхофф
# Words in category 74: серіал, поїзд, bmw, google, комісія, євро, корабель, міст, космічний, модель
# Words in category 75: зареєструвати, тонна, партія, супутник, модель, обраний, мандарин, нацрада, народний, депутат
# Words in category 76: маркл, меган, принц, мільйон, герцогиня, гаррі, королівський, кубометр, актриса, магазин
# Words in category 77: whatsapp, huawei, борода, bmw, смартфон, сша, програма, кпі, каннський, збій
# Words in category 78: тонна, невагомість, мандарин, група, дружина, будинок, ролик, пісня, 18pt, fontsize
# Words in category 79: кактус, місце, робот, млн, лідер, місцевий, тонна, нацрада, мандарин, росія
# Words in category 80: huawei, вечірка, телевізор, роналд, пожежний, польща, будинок, сигналізація, січень, співачка
# Words in category 81: січень, фсб, фючерсісти, стрілянина, 900, актор, електромобіль, грн, вартість, 737
# Words in category 82: кактус, пожежа, грн, травень, азс, кредит, ролик, гаєк, ціна, користувач
# Words in category 83: новий, uber, автомобіль, сезон, alibaba, кличко, естонія, німеччина, команда, apple
# Words in category 84: 18pt, fontsize, alibaba, кактус, модель, фото, бал, естонія, команда, гра
# Words in category 85: магазин, інвестор, україна, український, місцевий, січа, борода, зокрема, тейлор, uber
# Words in category 86: білка, google, мільйон, кубометр, 5g, актор, uber, інвестор, екхофф, січа
# Words in category 87: google, борода, мопс, поїзд, міг29, чиновник, операція, зареєструвати, виявитися, собака
# Words in category 88: борода, alibaba, каменський, alyona, співачка, курс, новий, 5g, мільйон, мережа
# Words in category 89: uber, укрпошта, борода, whatsapp, каланік, супутник, нафтогаз, група, будинок, земля
# Words in category 90: alibaba, каменський, співачка, мен, ялинка, міг29, оператор, барселона, кактус, серіал
# Words in category 91: новий, капуста, huawei, пасажир, хемілтон, роналд, авто, вистрибнути, повідомлення, 18pt
# Words in category 92: борода, укрпошта, млн, робот, магазин, тораєва, показати, рослинність, місто, 5g
# Words in category 93: міг29, січень, 900, український, підручний, четвер, актор, фючерсісти, грудень, робот
# Words in category 94: тонна, alibaba, мандарин, рейтинг, напій, тисяча, зозуля, альбасет, міст, азс
# Words in category 95: супутник, актор, альбасет, зозуля, фестиваль, каннський, кличко, смартфон, червень, нормандський
# Words in category 96: будинок, скласти, грн, супутник, автобус, смартфон, alibaba, україна, фільм, напій
# Words in category 97: ломаченко, василь, кролл, гольф, крим, фючерсісти, барселона, кпі, чемпіон, зазначити
# Words in category 98: зозуля, альбасет, новий, актор, ялинка, нацрада, whatsapp, райо, вальєкати, виробник
# Words in category 99: uber, український, alyona, фільм, 2020, санкція, тонна, напій, мандарин, каланік

# %%
ukr_text_df['category'] = X_lsa.argmax(axis=1)
ukr_text_df
# Out:
#                                       id  \
# 0     http://k.img.com.ua/rss/ua/4013798
# 1     http://k.img.com.ua/rss/ua/4001679
# 2     http://k.img.com.ua/rss/ua/4001390
# 3     http://k.img.com.ua/rss/ua/4001239
# 4     http://k.img.com.ua/rss/ua/4001227
# ...                                  ...
# 1117  http://k.img.com.ua/rss/ua/3194862
# 1118  http://k.img.com.ua/rss/ua/3194633
# 1119  http://k.img.com.ua/rss/ua/3194587
# 1120  http://k.img.com.ua/rss/ua/3194570
# 1121  http://k.img.com.ua/rss/ua/3194519
#
#                                                   title  \
# 0         Кличко покликав німецьких інвесторів до Києва
# 1     З'явилося відео, як байкер почав стріляти у во...
# 2           У центрі Києва посеред вулиці помер чоловік
# 3          Нічний ураган перетворив Хрещатик на смітник
# 4         Потоп у Києві: столицю накрив ураган з градом
# ...                                                 ...
# 1117  Корреспондент: Діамантові руки. Історія успіху...
# 1118  Корреспондент: Роздача слонів. Янукович щедро ...
# 1119  Корреспондент: Рівняння з трьома відомими. Укр...
# 1120  Корреспондент: Точка зору. Мета обкрадає кошти...
# 1121  Корреспондент: Капітан Океанів. Інтерв’ю зі Св...
#
#                                                    body  \
# 0     Київ - перспективний і відкритий ринок для біз...
# 1        З'явилося відео конфлікту між мотоциклістом...
# 2     У Києві на Бессарабській площі вранці в четвер...
# 3     Київ вночі 16 серпня пережив найсильнішу грозу...
# 4     Уночі Київ вкотре накрила негода. Найсильніший...
# ...                                                 ...
# 1117  Київський офіс Класичного ювелірного дому Лобо...
# 1118  20 років тому орден За заслуги – тоді він нази...
# 1119  10 жовтня політичні важковаговики з табору опо...
# 1120  Добре там, де нас немає. В Ізраїлі ми є, але т...
# 1121  Початок розмови Корреспондента зі знаменитим у...
#
#                                                   words      tone  \
# 0     [перспективний, відкритий, ринок, бізнес, інве...  0.026163
# 1     [зявитися, відео, конфлікт, мотоцикліст, водій... -0.090909
# 2     [бессарабський, площа, вранці, четвер, 16, сер... -0.137255
# 3     [вночі, 16, серпень, пережити, найсильніший, г...  0.000000
# 4     [уночі, вкотре, накрити, негода, найсильніший,...  0.000000
# ...                                                 ...       ...
# 1117  [київський, офіс, класичний, ювелірний, дома, ...  0.042616
# 1118  [20, том, орден, заслуга, називатися, почесний...  0.124682
# 1119  [10, жовтень, політичний, важковаговик, табір,...  0.022042
# 1120  [ізраїль, країна, займати, місце, світ, надій,...  0.018657
# 1121  [початок, розмова, корреспондент, знаменитий, ...  0.020802
#
#                                         normalized_text  category
# 0     перспективний відкритий ринок бізнес інвестиці...         0
# 1     зявитися відео конфлікт мотоцикліст водій авто...         0
# 2     бессарабський площа вранці четвер 16 серпень в...        21
# 3     вночі 16 серпень пережити найсильніший гроза з...        57
# 4     уночі вкотре накрити негода найсильніший дощ п...         0
# ...                                                 ...       ...
# 1117  київський офіс класичний ювелірний дома лоборт...         0
# 1118  20 том орден заслуга називатися почесний знак ...         0
# 1119  10 жовтень політичний важковаговик табір опози...         0
# 1120  ізраїль країна займати місце світ надій молоко...         0
# 1121  початок розмова корреспондент знаменитий украї...         0
#
# [1122 rows x 7 columns]
